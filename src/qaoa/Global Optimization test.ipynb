# %%
import multiprocessing
import matplotlib.pyplot as plt
import numpy
import scipy
import os
import pickle

# %%
path = "/Users/turbotanten/Documents/GitHub/cvqaoa/data/instances/max_cut_29/qaoa_parameters_level_1"
with open(path,"rb") as f:
    res = pickle.load(f)
# Generate start points on a sphere
size = 100
theta = numpy.pi * numpy.random.uniform(size=size) / 2 # beta
phi = numpy.arccos(2 * numpy.random.uniform(size=size) - 1) # alpha
plt.scatter(theta, phi, color='r', marker='o');
plt.imshow(res[3], extent=[0,numpy.pi/2,0,numpy.pi])
plt.xlabel(r'$\theta$');
plt.ylabel(r'$\phi$');
